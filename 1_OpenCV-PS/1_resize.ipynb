# %% [markdown]
# # OpenCV for Image Resize
# Resizing an image means changing the dimensions of it, be it width alone, height alone or changing both of them. Also, the aspect ratio of the original image could be preserved in the resized image. To resize an image, OpenCV provides cv2.resize() function.
#
# ![resize-2.jpg](attachment:resize-2.jpg)
#
# ##
# ## <center>Jupyter program

# %% [markdown]
# Import Library Opencv and Matplotlib

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read Image and convert From BGR to RGB

# %%
image = cv2.imread('./lena.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Original Image

# %%
width, height = image.shape[:2]
print("Image size: {}x{} pixels.".format(width, height))
# Out:
# Image size: 512x512 pixels.

# %%
_ = plt.imshow(image)

# %% [markdown]
# ## Resize Function Syntax
# ```python
# resize(src, dsize[, dst[, fx[, fy[, interpolation]]]])
# ```
#
# where :
#
#
# |Parameter|Description|
# |:---|:---|
# |src| [required] source/input image  |
# |dsize|  [required] desired size for the output image |
# |fx| [optional] scale factor along the horizontal axis  |
# |fy| [optional] scale factor along the vertical axis  |
# |interpolation|[optional] flag that takes one of the following methods. INTER_NEAREST – a nearest-neighbor interpolation INTER_LINEAR – a bilinear interpolation (used by default) INTER_AREA – resampling using pixel area relation. It may be a preferred method for image decimation, as it gives moire’-free results. But when the image is zoomed, it is similar to the INTER_NEAREST method. INTER_CUBIC – a bicubic interpolation over 4×4 pixel neighborhood INTER_LANCZOS4 – a Lanczos interpolation over 8×8 pixel neighborhood|

# %% [markdown]
# **> Image Resize By Scale**

# %%
scale_height = 0.25
scale_width  = 0.25
scaleImage = cv2.resize(image, (0,0), fx=scale_width, fy=scale_height)

# %%
width, height = scaleImage.shape[:2]
print("Resize Image by scale size: {}x{} pixels.".format(width, height))
# Out:
# Resize Image by scale size: 128x128 pixels.

# %%
_ = plt.imshow(scaleImage)

# %% [markdown]
# **> Resize Image By Pixel X * Y**

# %%
pixel_width  = 100
pixel_height = 100
scaleImage = cv2.resize(image, (pixel_width,pixel_height))

# %%
width, height = scaleImage.shape[:2]
print("Resize Image by pixel size: {}x{} pixels.".format(width, height))
# Out:
# Resize Image by pixel size: 100x100 pixels.

# %%
_ = plt.imshow(scaleImage)

# %% [markdown]
# Reference:
#
# [1] [https://docs.opencv.org/4.5.4/da/d6e/tutorial_py_geometric_transformations.html](https://docs.opencv.org/4.5.4/da/d6e/tutorial_py_geometric_transformations.html)
#
# [2] [https://docs.opencv.org/4.5.4/d2/d96/tutorial_py_table_of_contents_imgproc.html](https://docs.opencv.org/4.5.4/d2/d96/tutorial_py_table_of_contents_imgproc.html)
